# %% [markdown]
# <a href="https://colab.research.google.com/github/seenu-g/Experiments/blob/master/chap13/YOLOV3Trial500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# %load_ext autoreload
# %autoreload 2
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
import os
folder = '/content/gdrive/My Drive/school_of_ai/chap13/'
os.chdir(folder)
print(os.getcwd()) 
for items in os.listdir(folder):
   print(items)
sys.path.append(folder)
# Out:
# /content/gdrive/My Drive/school_of_ai/chap13
# annotations
# results.png
# YoloV3Trial.ipynb
# YoloV3_old
# YoloV3
# YOLOV3Trial500.ipynb

# %%
# !git clone https://github.com/theschoolofai/YoloV3

# %%
# %cd "/content/gdrive/My Drive/school_of_ai/chap13/YoloV3"
# Out:
# /content/gdrive/My Drive/school_of_ai/chap13/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output2	  results.txt	    train_batch0.png    weights
#  cfg		   __pycache__	  runs		    train.py
#  data		   README.md	  test_batch0.png  'ubdivisions=1'
#  detect.py	   results.json   test.py	    utils
#  models.py	   results.png	  ting		    vim.exe.stackdump

# %%
# !python "train.py" --data data/smalcoco/smalcoco.data --batch 10 --cache --epochs 5 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=5, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CPU
#
# 2020-04-24 11:02:03.991835: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 906.94it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 81.48it/s]
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 931.32it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 200 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=200, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# 2020-04-24 11:27:26.556877: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (448 found, 0 missing, 1 empty, 0 duplicate, for 449 images): 100% 449/449 [03:11<00:00,  2.35it/s]
# Caching images (0.2GB): 100% 449/449 [02:57<00:00,  2.53it/s]
# ...

# %%
from utils import utils
utils.plot_results()

# %%
# !python3 detect.py --weights weights/last.pt  --source "/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Toy story Woody & Buzz.mp4" --output "/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/output1"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/output1', save_txt=False, source='/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Toy story Woody & Buzz.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/3254) /content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Toy story Woody & Buzz.mp4: 320x512 1 woodys, Done. (0.020s)
# video 1/1 (2/3254) /content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Toy story Woody & Buzz.mp4: 320x512 1 woodys, Done. (0.017s)
# ...

# %%
# !python3 detect.py --weights weights/last.pt  --source "/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Hawaiian Vacation - Trailer.mp4" --output "/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/output2"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='output', save_txt=False, source='/content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Hawaiian Vacation - Trailer.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', total_memory=16280MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/2879) /content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Hawaiian Vacation - Trailer.mp4: 320x512 Done. (0.017s)
# video 1/1 (2/2879) /content/gdrive/My Drive/school_of_ai/chap13/YoloV3/data/customdata/Hawaiian Vacation - Trailer.mp4: 320x512 Done. (0.016s)
# ...
